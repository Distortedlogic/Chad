# %%
from src.model.chad_army import ChadArmy
# Out:
# it does not work
# it does not work
# it does not work
# it does not work
# it does not work
# it does not work

# %%
ChadArmy().war()
# Out:
# clear checkpoint save?
# ...

# %%
demichad.army.print_stats()
